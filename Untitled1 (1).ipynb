# %%
import pandas as pd 
df=pd.read_csv("DataAnalyst.csv")

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
def missing_values_table(data.fram)
# Out:
# array(['Vera Institute of Justice\n3.2',
#        'Visiting Nurse Service of New York\n3.8', 'Squarespace\n3.4', ...,
#        'Arrow Electronics\n2.9', 'Contingent Network Services\n3.1',
#        'SCL Health\n3.4'], dtype=object)

# %%
# Out:
#   Cell In[21], line 1
#     def missing_values_table(data.fram)
#                                  ^
# SyntaxError: invalid syntax

# %%
df["Company Name"].unique()
# Out:
# array(['Vera Institute of Justice\n3.2',
#        'Visiting Nurse Service of New York\n3.8', 'Squarespace\n3.4', ...,
#        'Arrow Electronics\n2.9', 'Contingent Network Services\n3.1',
#        'SCL Health\n3.4'], dtype=object)

# %%
import numpy as np

# %%
df=df.replace(-1,np.nan)
df=df.replace(-1.0,np.nan)
df=df.replace("-1",np.nan)

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
df["Rating"]=df["Rating"].fillna(0).astype(float)

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
df["Easy Apply"]=df["Easy Apply"].fillna(False).astype(bool)

# %%
df["Easy Apply"].value_counts()
# Out:
# Easy Apply
# False    2173
# True       80
# Name: count, dtype: int64

# %%
df["Rating"]=df["Rating"].fillna(0).astype(float)

# %%
df["Rating"].value_counts()
# Out:
# Rating
# 0.0    272
# 3.9    140
# 3.6    135
# 3.7    132
# 5.0    131
# 3.8    130
# 4.0    129
# 3.5    125
# 4.1    119
# 3.3    109
# 3.4    101
# 3.2     91
# 3.1     68
# 3.0     57
# 4.3     55
# 4.2     47
# 4.5     47
# 4.6     46
# 4.4     46
# 2.8     43
# 2.9     40
# 2.5     32
# 4.8     29
# 2.7     25
# 4.7     23
# 4.9     17
# 2.6     14
# 1.0     10
# 2.4     10
# 2.3      9
# 2.0      6
# 2.1      4
# 2.2      3
# 1.7      2
# 1.8      2
# 1.6      2
# 1.9      2
# Name: count, dtype: int64

# %%
df.dropna(subset=["Salary Estimate","Company Name"],inplace=True)

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
for column in df.columns:
    if df[column].dtype=="object":
        df[column].fillna("unkonwn",inplace=True)
    else:
        df[column].fillna(0,inplace=True)

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
min_salaries=[]
max_salaries=[]
for salary in df["Salary Estimate"]:
    salary_range=salary.split(" ")[0].split("-")
    min_salary=salary_range[0].replace("$"," ").replace("k","")
    max_salary=salary_range[0].replace("$"," ").replace("k","")
    min_salaries.append(min_salary)
    max_salaries.append(max_salary)
df["min_salary (k) "]=min_salaries
df["max_salary (k) "]=max_salaries

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
Job_Titles=[]
departmentes=[]
for i in df["Job Title"]:
    title_parts=i.split(",")
    if len(title_parts)==2:
        Job_Titles.append(title_parts[0])
        departmentes.append(title_parts[1])
    else:
        Job_Titles.append(title_parts[0])
        departmentes.append("unkowen")
df['Job Title'] = Job_Titles
df['departmentes']=departmentes

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                                       Data Analyst
# 1              1                               Quality Data Analyst
# 2              2                                Senior Data Analyst
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250                    Technical Business Analyst (SQL
# 2251        2251                                     Data Analyst 3
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
Loction_Titles=[]
states=[]
for i in df["Location"]:
    title_parts=i.split(",")
    if len(title_parts)==2:
        Loction_Titles.append(title_parts[0])
        states.append(title_parts[1])
    else:
        Loction_Titles.append(title_parts[0])
        states.append("unkowen")
df['Location'] = Loction_Titles
df['states']=states

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                                       Data Analyst
# 1              1                               Quality Data Analyst
# 2              2                                Senior Data Analyst
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250                    Technical Business Analyst (SQL
# 2251        2251                                     Data Analyst 3
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
Loction_Titles=[]
states=[]
for i in df["Location"]:
    title_parts=i.split(",")
    if len(title_parts)==2:
        Loction_Titles.append(title_parts[0])
        states.append(title_parts[1])
    else:
        Loction_Titles.append(title_parts[0])
        states.append("unkowen")
df['Location'] = Loction_Titles
df['states']=states

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                                       Data Analyst
# 1              1                               Quality Data Analyst
# 2              2                                Senior Data Analyst
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250                    Technical Business Analyst (SQL
# 2251        2251                                     Data Analyst 3
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
#data drop
#df.drop([Location],axis=1,inplace=True)

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                                       Data Analyst
# 1              1                               Quality Data Analyst
# 2              2                                Senior Data Analyst
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250                    Technical Business Analyst (SQL
# 2251        2251                                     Data Analyst 3
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
df.groupby("Company Name")["Rating"].mea

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                                       Data Analyst
# 1              1                               Quality Data Analyst
# 2              2                                Senior Data Analyst
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250                    Technical Business Analyst (SQL
# 2251        2251                                     Data Analyst 3
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
#maximum salary "max_salary (k) "
#df[df["max_salary (k) "]==df["max_salary (k) "]["sector"]
df.groupby("Sector")["max_salary (k) "].max()
# Out:
# Sector
# Accounting & Legal                     93K
# Aerospace & Defense                    76K
# Arts, Entertainment & Recreation       73K
# Biotech & Pharmaceuticals              97K
# Business Services                      99K
# Construction, Repair & Maintenance     67K
# Consumer Services                      89K
# Education                              76K
# Finance                                99K
# Government                             93K
# Health Care                            99K
# Information Technology                 99K
# Insurance                              98K
# Manufacturing                          99K
# Media                                  84K
# Mining & Metals                        41K
# Non-Profit                             73K
# Oil, Gas, Energy & Utilities           77K
# Real Estate                            99K
# Restaurants, Bars & Food Services      48K
# Retail                                 99K
# Telecommunications                     78K
# ...

# %%
#oldest companyn 
df["Founded"].sort_values(ascending = True)
# Out:
# 733        0.0
# 1309       0.0
# 1300       0.0
# 1295       0.0
# 1292       0.0
#          ...
# 36      2018.0
# 592     2019.0
# 1835    2019.0
# 991     2019.0
# 979     2019.0
# Name: Founded, Length: 2251, dtype: float64

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                                       Data Analyst
# 1              1                               Quality Data Analyst
# 2              2                                Senior Data Analyst
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250                    Technical Business Analyst (SQL
# 2251        2251                                     Data Analyst 3
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
#number of companies in each location
df.groupby('states')['Company Name'].count().sort_values(ascending=False)
# Out:
# states
# unkowen    2251
# Name: Company Name, dtype: int64

# %%
df.to_csv('DataAnalyst_cleaned.csv')
